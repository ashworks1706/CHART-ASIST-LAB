# %% [markdown]
# # Multi-Modal Data Analysis Workflow
# **ASIST Study 3 Dataset**
#
#
# ## Objective
# Analyze team performance data across four modalities:
# 1. JSON behavior logs
# 2. SPSS survey responses
# 3. Video recordings
# 4. Chat transcripts
#
# Identify correlations between AI interventions and team outcomes.
#
# ## Note
#
# All datasets were taken from official CHART ASIST Study 3 Dataset available at ASU official repository.
#
# #### Subset used :
#
# | Team ID   | ASI ID            | trial | intervention_recipent |
# |--------|----------------|-------|---------------|
# | 000315 | ASI-CMURI-TA1         | T000829 | E001211, E001215, E001155 |

# %% [markdown]
# ## Installing dependencies

# %%
# %pip install opencv-python pandas scikit-learn matplotlib torch

# %%
import cv2
from pathlib import Path
import json
import pandas as pd
# import openai
import matplotlib.pyplot as plt
import os
# import torch
import json

# %% [markdown]
# # Preparing Dataset

# %% [markdown]
# ### 1. JSON Logs Processing
# #### Objective
# Extract structured data from nested JSON logs containing:
# - Team actions
# - AI intervention timestamps
# - Mission outcomes

# %%
# def parse_json_logs(input_path: Path, output_path: Path) -> pd.DataFrame:
#     """Flatten nested JSON logs into structured format"""
#     with open(input_path, 'r') as f:
#         data = [json.loads(line) for line in f]
    
#     df = pd.json_normalize(data, sep='_')
#     df.to_csv(output_path, index=False)
#     return df

# # Process all trial messages
# input_files = [
#     Path("data/json_logs/HSRData_TrialMessages_Trial-T000603_..."),
#     Path("data/json_logs/HSRData_TrialMessages_Trial-T000639_..."),
#     Path("data/json_logs/HSRData_TrialMessages_Trial-T000671_...")
# ]

# output_dir = Path("data/processed/json_parsed/")
# output_dir.mkdir(parents=True, exist_ok=True)

# for file in input_files:
#     output_file = output_dir / f"{file.stem}_parsed.csv"
#     df = parse_json_logs(file, output_file)
#     print(f"Processed {len(df)} records from {file.name}")

# %% [markdown]
# ### 2. Video Analysis
# #### Objective
# Extract key frames every 10 seconds for:
# - Activity pattern analysis
# - Non-verbal communication study

# %%
# import cv2
# import os
# from pathlib import Path

# def extract_frames(video_path: Path, output_dir: Path, interval: int = 10):
#     """Extract frames at fixed intervals (default: 10 seconds)"""
#     vidcap = cv2.VideoCapture(str(video_path))
#     if not vidcap.isOpened():
#         print(f"Error opening video: {video_path}")
#         return
    
#     fps = vidcap.get(cv2.CAP_PROP_FPS)
#     frame_interval = int(fps * interval)
    
#     count = 0
#     while vidcap.isOpened():
#         success, frame = vidcap.read()
#         if not success: 
#             break
#         if count % frame_interval == 0:
#             cv2.imwrite(str(output_dir / f"frame_{count:04d}.jpg"), frame)
#         count += 1
#     vidcap.release()

# # Configuration
# video_dir = Path("../data/videos/")
# output_base_dir = Path("../processed_data/")
# output_base_dir.mkdir(parents=True, exist_ok=True)

# # Process all MP4 files
# for idx, video_file in enumerate(video_dir.glob("*.mp4"), start=1):
#     folder_path = output_base_dir / str(idx)
#     folder_path.mkdir(parents=True, exist_ok=True)
    
#     print(f"Processing {video_file.name} -> Folder {idx}")
#     extract_frames(video_file, folder_path)

# %% [markdown]
# # Data Analysis

# %% [markdown]
# ## Transciption data analysis

# %%
df = pd.read_csv("/mnt/c/Users/Som/Desktop/CHART ASIST/Study3_Analysis/data/transcripts/transcript.csv")

# %%
df.head(5)
# Out:
#      trial      team  scenario      date timestamp            asi  \
# 0  T000829  TM000315  Saturn_C  7/8/2022  22:55:55  ASI-CMURI-TA1
# 1  T000829  TM000315  Saturn_C  7/8/2022  22:56:10  ASI-CMURI-TA1
# 2  T000829  TM000315  Saturn_C  7/8/2022  22:56:16  ASI-CMURI-TA1
# 3  T000829  TM000315  Saturn_C  7/8/2022  22:56:18  ASI-CMURI-TA1
# 4  T000829  TM000315  Saturn_C  7/8/2022  22:56:29  ASI-CMURI-TA1
#
#                                 intervention_message  \
# 0  Hello, I am ATLAS, and will be providing advic...
# 1                                                 {}
# 2                                                 {}
# 3                                                 {}
# 4                                                 {}
#
#                intervention_recipent  \
# 0  ['E001211', 'E001215', 'E001155']
# 1                                 {}
# 2                                 {}
# 3                                 {}
# 4                                 {}
#
#                                       speech_message  medic  transporter  \
# 0                                                 {}      1            1
# 1  okay this is engineer room tool with known dam...      0            0
# 2  so most likely to be critical victims in those...      0            0
# 3                 can you repeat that again engineer      1            0
# 4  okay I3 A2 E2 and A2 have rooms with known dam...      0            0
#
#    engineer                                        explanation
# 0         1  {'info': {'default_message': 'Hello, I am ATLA...
# 1         1                                                 {}
# 2         1                                                 {}
# 3         0                                                 {}
# 4         1                                                 {}

# %%
df = df[1:]

# %% [markdown]
# #### Removing useless columns
#
# Originally it had many columns and we reduced it down to only the ones which had data

# %%
df["asi_message"] = df["intervention_message"].replace("{}", "")
df["team_message"] = df["speech_message"].replace("{}", "")

# %% [markdown]
# Adding a intervention_class column from explanation string

# %%
# Extract intervention_class from explanation strings
df['intervention_class'] = df['explanation'].str.extract(
    r"'intervention_class'\s*:\s*'([^']*)'"
)
df["intervention_class"] = df["intervention_class"].replace("Intervention", "")
# Create binary columns for each unique intervention class
intervention_classes = df['intervention_class'].dropna().unique()
for cls in intervention_classes:
    df[cls] = df['intervention_class'].eq(cls).astype(int)

# Cleanup intermediate column
df = df.drop(columns=['intervention_class'])

# %% [markdown]
# We don't need unique team ids, asi ids, date, trial id, intervention_recipent id or explanation since we have extracted the unique class

# %%
df = df.drop(columns=["team","asi","date","timestamp","explanation","intervention_recipent","intervention_message","speech_message","trial"], axis=1)

# %%
df.sample(19)
# Out:
#      scenario  medic  transporter  engineer  \
# 106  Saturn_C      0            1         0
# 156  Saturn_C      1            0         0
# 142  Saturn_C      1            0         0
# 73   Saturn_C      0            0         1
# 113  Saturn_C      1            0         0
# 205  Saturn_D      1            0         0
# 132  Saturn_C      1            0         0
# 67   Saturn_C      1            0         0
# 91   Saturn_C      1            0         0
# 20   Saturn_C      1            0         0
# 237  Saturn_D      0            1         0
# 53   Saturn_C      0            0         1
# 168  Saturn_D      0            0         1
# 102  Saturn_C      1            0         0
# 298  Saturn_D      1            0         0
# 186  Saturn_D      0            0         1
# 103  Saturn_C      0            0         1
# 146  Saturn_C      0            1         0
# 171  Saturn_D      1            0         0
#
#                                            asi_message  \
# 106  Transporters focusing on marking rooms and eva...
# 156
# 142  Medic, if your team was informed that a victim...
# 73
# 113
# 205
# 132
# 67
# 91
# 20
# 237  Green, there is a victim nearby that can be mo...
# 53
# 168
# 102
# 298
# 186
# 103
# 146
# 171
#
#                                           team_message  \
# 106
# 156                  my husband now only on the screen
# 142
# 73                                      are you in c 1
# 113  I think you need to close or engineer to the v...
# 205                                               Ange
# 132   transport this critical victim perfect thank you
# 67                     transporter are you in the room
# 91                           it is yes and is a a type
# 20           engineer this is medic I'm located and D2
# 237
# 53                                           friend D2
# 168  yeah and B5 F2 and E3 are severe damage to roo...
# 102  medic to rest of Team I'll be checking out C4 ...
# 298                                      I see none in
# 186                                               yeah
# 103                                               okay
# 146                                               yeah
# 171                                              first
#
#      RemindTransporterBeepsIntervention  \
# 106                                   0
# 156                                   0
# 142                                   0
# 73                                    0
# 113                                   0
# 205                                   0
# 132                                   0
# 67                                    0
# 91                                    0
# 20                                    0
# 237                                   0
# 53                                    0
# 168                                   0
# 102                                   0
# 298                                   0
# 186                                   0
# 103                                   0
# 146                                   0
# 171                                   0
#
#      InformAboutTriagedVictimsIntervention  \
# 106                                      0
# 156                                      0
# 142                                      0
# 73                                       0
# 113                                      0
# 205                                      0
# 132                                      0
# 67                                       0
# 91                                       0
# 20                                       0
# 237                                      1
# 53                                       0
# 168                                      0
# 102                                      0
# 298                                      0
# 186                                      0
# 103                                      0
# 146                                      0
# 171                                      0
#
#      RemindMedicToInformAboutTriagedVictimIntervention  \
# 106                                                  0
# 156                                                  0
# 142                                                  1
# 73                                                   0
# 113                                                  0
# 205                                                  0
# 132                                                  0
# 67                                                   0
# 91                                                   0
# 20                                                   0
# 237                                                  0
# 53                                                   0
# 168                                                  0
# 102                                                  0
# 298                                                  0
# 186                                                  0
# 103                                                  0
# 146                                                  0
# 171                                                  0
#
#      TriageCriticalVictimsIntervention  ...  \
# 106                                  0  ...
# 156                                  0  ...
# 142                                  0  ...
# 73                                   0  ...
# 113                                  0  ...
# 205                                  0  ...
# 132                                  0  ...
# 67                                   0  ...
# 91                                   0  ...
# 20                                   0  ...
# 237                                  0  ...
# 53                                   0  ...
# 168                                  0  ...
# 102                                  0  ...
# 298                                  0  ...
# 186                                  0  ...
# 103                                  0  ...
# 146                                  0  ...
# 171                                  0  ...
#
#      EncouragePlayerProximityToMedicIHMCDyad  RemindChangeMarkerIntervention  \
# 106                                        1                               0
# 156                                        0                               0
# 142                                        0                               0
# 73                                         0                               0
# 113                                        0                               0
# 205                                        0                               0
# 132                                        0                               0
# 67                                         0                               0
# 91                                         0                               0
# 20                                         0                               0
# 237                                        0                               0
# 53                                         0                               0
# 168                                        0                               0
# 102                                        0                               0
# 298                                        0                               0
# 186                                        0                               0
# 103                                        0                               0
# 146                                        0                               0
# 171                                        0                               0
#
#      RemindRubblePerturbationIntervention  EvacuationZoneDistanceIntervention  \
# 106                                     0                                   0
# 156                                     0                                   0
# 142                                     0                                   0
# 73                                      0                                   0
# 113                                     0                                   0
# 205                                     0                                   0
# 132                                     0                                   0
# 67                                      0                                   0
# 91                                      0                                   0
# 20                                      0                                   0
# 237                                     0                                   0
# 53                                      0                                   0
# 168                                     0                                   0
# 102                                     0                                   0
# 298                                     0                                   0
# 186                                     0                                   0
# 103                                     0                                   0
# 146                                     0                                   0
# 171                                     0                                   0
#
#      TeamSawVictimMarkerIntervention  TimeElapsedIntervention  \
# 106                                0                        0
# 156                                0                        0
# 142                                0                        0
# 73                                 0                        0
# 113                                0                        0
# 205                                0                        0
# 132                                0                        0
# 67                                 0                        0
# 91                                 0                        0
# 20                                 0                        0
# 237                                0                        0
# 53                                 0                        0
# 168                                0                        0
# 102                                0                        0
# 298                                0                        0
# 186                                0                        0
# 103                                0                        0
# 146                                0                        0
# 171                                0                        0
#
#      StartEvacuationIntervention  TeamWelcomeMessageIntervention  \
# 106                            0                               0
# 156                            0                               0
# 142                            0                               0
# 73                             0                               0
# 113                            0                               0
# 205                            0                               0
# 132                            0                               0
# 67                             0                               0
# 91                             0                               0
# 20                             0                               0
# 237                            0                               0
# 53                             0                               0
# 168                            0                               0
# 102                            0                               0
# 298                            0                               0
# 186                            0                               0
# 103                            0                               0
# 146                            0                               0
# 171                            0                               0
#
#      TransporterEarlyStrategyIntervention  TriagedVictimMarkerIntervention
# 106                                     0                                0
# 156                                     0                                0
# 142                                     0                                0
# 73                                      0                                0
# 113                                     0                                0
# 205                                     0                                0
# 132                                     0                                0
# 67                                      0                                0
# 91                                      0                                0
# 20                                      0                                0
# 237                                     0                                0
# 53                                      0                                0
# 168                                     0                                0
# 102                                     0                                0
# 298                                     0                                0
# 186                                     0                                0
# 103                                     0                                0
# 146                                     0                                0
# 171                                     0                                0
#
# [19 rows x 21 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 310 entries, 1 to 310
# Data columns (total 21 columns):
#  #   Column                                             Non-Null Count  Dtype
# ---  ------                                             --------------  -----
#  0   scenario                                           310 non-null    object
#  1   medic                                              310 non-null    int64
#  2   transporter                                        310 non-null    int64
#  3   engineer                                           310 non-null    int64
#  4   asi_message                                        310 non-null    object
#  5   team_message                                       310 non-null    object
#  6   RemindTransporterBeepsIntervention                 310 non-null    int64
#  7   InformAboutTriagedVictimsIntervention              310 non-null    int64
#  8   RemindMedicToInformAboutTriagedVictimIntervention  310 non-null    int64
#  9   TriageCriticalVictimsIntervention                  310 non-null    int64
#  10  EvacuateCriticalVictimsIntervention                310 non-null    int64
#  11  EncouragePlayerProximityToMedicIHMCDyad            310 non-null    int64
#  12  RemindChangeMarkerIntervention                     310 non-null    int64
#  13  RemindRubblePerturbationIntervention               310 non-null    int64
#  14  EvacuationZoneDistanceIntervention                 310 non-null    int64
#  15  TeamSawVictimMarkerIntervention                    310 non-null    int64
#  16  TimeElapsedIntervention                            310 non-null    int64
#  17  StartEvacuationIntervention                        310 non-null    int64
#  18  TeamWelcomeMessageIntervention                     310 non-null    int64
#  19  TransporterEarlyStrategyIntervention               310 non-null    int64
#  20  TriagedVictimMarkerIntervention                    310 non-null    int64
# dtypes: int64(18), object(3)
# memory usage: 51.0+ KB
